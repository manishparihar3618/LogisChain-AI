# %% [markdown]
# #### EDA on smart_logistics_dataset

# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("../data/smart_logistics_dataset.csv")

# %%
df.head()
# Out:
#              Timestamp  Asset_ID  Latitude  Longitude  Inventory_Level  \
# 0  2024-03-20 00:11:14   Truck_7  -65.7383    11.2497              390
# 1  2024-10-30 07:53:51   Truck_6   22.2748  -131.7086              491
# 2  2024-07-29 18:42:48  Truck_10   54.9232    79.5455              190
# 3  2024-10-28 00:50:54   Truck_9   42.3900    -1.4788              330
# 4  2024-09-27 15:52:58   Truck_7  -65.8477    47.9468              480
#
#   Shipment_Status  Temperature  Humidity Traffic_Status  Waiting_Time  \
# 0         Delayed         27.0      67.8         Detour            38
# 1      In Transit         22.5      54.3          Heavy            16
# 2      In Transit         25.2      62.2         Detour            34
# 3       Delivered         25.4      52.3          Heavy            37
# 4         Delayed         20.5      57.2          Clear            56
#
#    User_Transaction_Amount  User_Purchase_Frequency Logistics_Delay_Reason  \
# ...

# %%
df.shape
# Out:
# (1000, 16)

# %%
df.columns
# Out:
# Index(['Timestamp', 'Asset_ID', 'Latitude', 'Longitude', 'Inventory_Level',
#        'Shipment_Status', 'Temperature', 'Humidity', 'Traffic_Status',
#        'Waiting_Time', 'User_Transaction_Amount', 'User_Purchase_Frequency',
#        'Logistics_Delay_Reason', 'Asset_Utilization', 'Demand_Forecast',
#        'Logistics_Delay'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Timestamp                1000 non-null   object
#  1   Asset_ID                 1000 non-null   object
#  2   Latitude                 1000 non-null   float64
#  3   Longitude                1000 non-null   float64
#  4   Inventory_Level          1000 non-null   int64
#  5   Shipment_Status          1000 non-null   object
#  6   Temperature              1000 non-null   float64
#  7   Humidity                 1000 non-null   float64
#  8   Traffic_Status           1000 non-null   object
#  9   Waiting_Time             1000 non-null   int64
#  10  User_Transaction_Amount  1000 non-null   int64
#  11  User_Purchase_Frequency  1000 non-null   int64
#  12  Logistics_Delay_Reason   737 non-null    object
#  13  Asset_Utilization        1000 non-null   float64
# ...

# %%
df.describe()
# Out:
#           Latitude    Longitude  Inventory_Level  Temperature     Humidity  \
# count  1000.000000  1000.000000      1000.000000  1000.000000  1000.000000
# mean     -1.360093     0.837049       297.915000    23.893900    65.042200
# std      51.997183   104.843618       113.554773     3.322178     8.753765
# min     -89.791500  -179.820200       100.000000    18.000000    50.000000
# 25%     -46.167975   -88.448075       201.000000    21.200000    57.200000
# 50%      -4.503150     0.678300       299.000000    23.800000    65.200000
# 75%      44.502800    88.156450       399.000000    26.600000    72.400000
# max      89.870100   179.923700       500.000000    30.000000    80.000000
#
#        Waiting_Time  User_Transaction_Amount  User_Purchase_Frequency  \
# count   1000.000000              1000.000000              1000.000000
# mean      35.062000               299.055000                 5.513000
# std       14.477768               117.787792                 2.935379
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Timestamp                    0
# Asset_ID                     0
# Latitude                     0
# Longitude                    0
# Inventory_Level              0
# Shipment_Status              0
# Temperature                  0
# Humidity                     0
# Traffic_Status               0
# Waiting_Time                 0
# User_Transaction_Amount      0
# User_Purchase_Frequency      0
# Logistics_Delay_Reason     263
# Asset_Utilization            0
# Demand_Forecast              0
# Logistics_Delay              0
# dtype: int64

# %%
df.dtypes
# Out:
# Timestamp                   object
# Asset_ID                    object
# Latitude                   float64
# Longitude                  float64
# Inventory_Level              int64
# Shipment_Status             object
# Temperature                float64
# Humidity                   float64
# Traffic_Status              object
# Waiting_Time                 int64
# User_Transaction_Amount      int64
# User_Purchase_Frequency      int64
# Logistics_Delay_Reason      object
# Asset_Utilization          float64
# Demand_Forecast              int64
# Logistics_Delay              int64
# dtype: object

# %%
df.select_dtypes(include="number")
# Out:
#      Latitude  Longitude  Inventory_Level  Temperature  Humidity  \
# 0    -65.7383    11.2497              390         27.0      67.8
# 1     22.2748  -131.7086              491         22.5      54.3
# 2     54.9232    79.5455              190         25.2      62.2
# 3     42.3900    -1.4788              330         25.4      52.3
# 4    -65.8477    47.9468              480         20.5      57.2
# ..        ...        ...              ...          ...       ...
# 995   89.8701    73.6867              264         26.9      70.0
# 996  -10.4792  -177.1239              479         23.7      77.9
# 997  -71.0609    75.3714              347         21.0      63.1
# 998  -76.7910    18.3631              276         18.0      64.3
# 999   59.8356  -114.4198              157         18.7      73.6
#
#      Waiting_Time  User_Transaction_Amount  User_Purchase_Frequency  \
# 0              38                      320                        4
# ...

# %%
df.select_dtypes(include="object")
# Out:
#                Timestamp  Asset_ID Shipment_Status Traffic_Status  \
# 0    2024-03-20 00:11:14   Truck_7         Delayed         Detour
# 1    2024-10-30 07:53:51   Truck_6      In Transit          Heavy
# 2    2024-07-29 18:42:48  Truck_10      In Transit         Detour
# 3    2024-10-28 00:50:54   Truck_9       Delivered          Heavy
# 4    2024-09-27 15:52:58   Truck_7         Delayed          Clear
# ..                   ...       ...             ...            ...
# 995  2024-07-22 16:30:00   Truck_6       Delivered          Heavy
# 996  2024-04-30 04:58:58   Truck_5       Delivered         Detour
# 997  2024-10-27 22:09:13   Truck_2      In Transit         Detour
# 998  2024-04-18 23:06:56   Truck_2       Delivered          Heavy
# 999  2024-09-18 19:39:24   Truck_8         Delayed          Clear
#
#     Logistics_Delay_Reason
# 0                      NaN
# 1                  Weather
# 2                      NaN
# 3                  Traffic
# 4                      NaN
# ...

# %% [markdown]
# ### Understanding every Feature
#
# #### (1)  Timestamp :- Datetime
# -> Shipment Date and Time
#
#
# #### (2) Asset_ID :- Categorical
# -> Truck ID
#
#
# #### (3) Latitude :- Numerical
# -> Vehicle location
#
#
# #### (4) Longitude :-

# %%
df["Logistics_Delay"].value_counts()
# Out:
# Logistics_Delay
# 1    566
# 0    434
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="Logistics_Delay",data=df)
plt.title("Distribution of Logistics Delay")
plt.show()

# %%
df["Shipment_Status"].value_counts()
# Out:
# Shipment_Status
# Delayed       350
# Delivered     338
# In Transit    312
# Name: count, dtype: int64

# %%
df["Traffic_Status"].value_counts()
# Out:
# Traffic_Status
# Detour    345
# Clear     328
# Heavy     327
# Name: count, dtype: int64

# %%
df["Logistics_Delay_Reason"].value_counts()
# Out:
# Logistics_Delay_Reason
# Weather               267
# Traffic               236
# Mechanical Failure    234
# Name: count, dtype: int64

# %%
pd.crosstab(df["Traffic_Status"],df["Logistics_Delay"])
# Out:
# Logistics_Delay    0    1
# Traffic_Status
# Clear            213  115
# Detour           221  124
# Heavy              0  327

# %%
plt.figure(figsize=(7,4))
sns.boxplot(
    x="Logistics_Delay",
    y="Temperature",
    data=df
)
plt.title("Temperature vs Logistics Delay")
plt.show()
